# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Dataset

# %%
df = pd.read_csv("wisc_bc_data.csv")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  87139402         B        12.32         12.39           78.85      464.1
# 1   8910251         B        10.60         18.95           69.28      346.4
# 2    905520         B        11.04         16.83           70.92      373.2
# 3    868871         B        11.28         13.39           73.00      384.8
# 4   9012568         B        15.19         13.21           97.65      711.8
#
#    smoothness_mean  compactness_mean  concavity_mean  points_mean  ...  \
# 0          0.10280           0.06981         0.03987      0.03700  ...
# 1          0.09688           0.11470         0.06387      0.02642  ...
# 2          0.10770           0.07804         0.03046      0.02480  ...
# 3          0.11640           0.11360         0.04635      0.04796  ...
# 4          0.07963           0.06934         0.03393      0.02657  ...
#
#    radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# ...

# %%
df.shape
# Out:
# (569, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 569 non-null    int64
#  1   diagnosis          569 non-null    object
#  2   radius_mean        569 non-null    float64
#  3   texture_mean       569 non-null    float64
#  4   perimeter_mean     569 non-null    float64
#  5   area_mean          569 non-null    float64
#  6   smoothness_mean    569 non-null    float64
#  7   compactness_mean   569 non-null    float64
#  8   concavity_mean     569 non-null    float64
#  9   points_mean        569 non-null    float64
#  10  symmetry_mean      569 non-null    float64
#  11  dimension_mean     569 non-null    float64
#  12  radius_se          569 non-null    float64
#  13  texture_se         569 non-null    float64
#  14  perimeter_se       569 non-null    float64
# ...

# %%
df["diagnosis"].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
df["diagnosis"] = df["diagnosis"].astype("category")

# %%
df.describe().T
# Out:
#                    count          mean           std          min  \
# id                 569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean        569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean       569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean     569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean          569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean    569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean   569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean     569.0  8.879932e-02  7.971981e-02     0.000000
# points_mean        569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean      569.0  1.811619e-01  2.741428e-02     0.106000
# dimension_mean     569.0  6.279761e-02  7.060363e-03     0.049960
# radius_se          569.0  4.051721e-01  2.773127e-01     0.111500
# texture_se         569.0  1.216853e+00  5.516484e-01     0.360200
# ...

# %% [markdown]
# ### Checking for the missing values

# %%
df.isnull().sum()
# Out:
# id                   0
# diagnosis            0
# radius_mean          0
# texture_mean         0
# perimeter_mean       0
# area_mean            0
# smoothness_mean      0
# compactness_mean     0
# concavity_mean       0
# points_mean          0
# symmetry_mean        0
# dimension_mean       0
# radius_se            0
# texture_se           0
# perimeter_se         0
# area_se              0
# smoothness_se        0
# compactness_se       0
# concavity_se         0
# points_se            0
# symmetry_se          0
# dimension_se         0
# radius_worst         0
# texture_worst        0
# perimeter_worst      0
# area_worst           0
# smoothness_worst     0
# compactness_worst    0
# concavity_worst      0
# points_worst         0
# symmetry_worst       0
# dimension_worst      0
# dtype: int64

# %% [markdown]
# # Machine Learning

# %%
X = df[df.columns[2:]]
y = df["diagnosis"]

# %%
X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        12.32         12.39           78.85      464.1          0.10280
# 1        10.60         18.95           69.28      346.4          0.09688
# 2        11.04         16.83           70.92      373.2          0.10770
# 3        11.28         13.39           73.00      384.8          0.11640
# 4        15.19         13.21           97.65      711.8          0.07963
#
#    compactness_mean  concavity_mean  points_mean  symmetry_mean  \
# 0           0.06981         0.03987      0.03700         0.1959
# 1           0.11470         0.06387      0.02642         0.1922
# 2           0.07804         0.03046      0.02480         0.1714
# 3           0.11360         0.04635      0.04796         0.1771
# 4           0.06934         0.03393      0.02657         0.1721
#
#    dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
y.head()
# Out:
# 0    B
# 1    B
# 2    B
# 3    B
# 4    B
# Name: diagnosis, dtype: category
# Categories (2, object): ['B', 'M']

# %% [markdown]
# ### Scaling the Numeric Attributes

# %%
from scipy import stats

# %%
X = X.apply(stats.zscore)

# %%
X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0    -0.513297     -1.605595       -0.540376  -0.542624         0.458285
# 1    -1.001801     -0.079038       -0.934566  -0.877375         0.036986
# 2    -0.876835     -0.572377       -0.867014  -0.801153         0.806996
# 3    -0.808671     -1.372888       -0.781338  -0.768161         1.426135
# 4     0.301824     -1.414775        0.234000   0.161860        -1.190618
#
#    compactness_mean  concavity_mean  points_mean  symmetry_mean  \
# 0         -0.654413       -0.614306    -0.307442       0.538081
# 1          0.196319       -0.312987    -0.580343       0.402996
# 2         -0.498443       -0.732448    -0.622129      -0.356400
# 3          0.175472       -0.532950    -0.024740      -0.148296
# 4         -0.663320       -0.688883    -0.576473      -0.330843
#
#    dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
# Alternate Method
X1 = df[df.columns[2:]]
X1 = (X1 - X1.mean()) / X1.std()
X1.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0    -0.512845     -1.604183       -0.539901  -0.542147         0.457883
# 1    -1.000920     -0.078969       -0.933744  -0.876603         0.036954
# 2    -0.876064     -0.571874       -0.866252  -0.800448         0.806287
# 3    -0.807960     -1.371681       -0.780651  -0.767486         1.424882
# 4     0.301559     -1.413531        0.233794   0.161718        -1.189571
#
#    compactness_mean  concavity_mean  points_mean  symmetry_mean  \
# 0         -0.653838       -0.613766    -0.307172       0.537608
# 1          0.196146       -0.312712    -0.579832       0.402642
# 2         -0.498004       -0.731805    -0.621582      -0.356087
# 3          0.175318       -0.532481    -0.024718      -0.148166
# 4         -0.662737       -0.688277    -0.575967      -0.330553
#
#    dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# ### Splitting the Data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %% [markdown]
# ### Applying kNN Algorithm

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
kNN_model = KNeighborsClassifier(n_neighbors=5, weights="distance")

# %%
kNN_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(weights='distance')

# %%
y_pred = kNN_model.predict(X_test)

# %%
y_pred[:5]
# Out:
# array(['M', 'M', 'M', 'M', 'B'], dtype=object)

# %% [markdown]
# # Evaluating the performance of kNN model

# %%
kNN_model.score(X_test, y_test)
# Out:
# 0.9649122807017544

# %%
from sklearn import metrics

# %%
cm = metrics.confusion_matrix(y_test, y_pred, labels=["M", "B"])
cm
# Out:
# array([[ 53,   4],
#        [  2, 112]], dtype=int64)

# %%
cm_display = metrics.ConfusionMatrixDisplay(cm, display_labels=["M", "B"])
cm_display.plot()

# %%
print("Classification Report: \n")
print(metrics.classification_report(y_test, y_pred, labels=["M", "B"]))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            M       0.96      0.93      0.95        57
#            B       0.97      0.98      0.97       114
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.96      0.96       171
# weighted avg       0.96      0.96      0.96       171

# %% [markdown]
# ### Chosing k-value

# %%
scores = {}
for k in range(1, 50):
    kNN = KNeighborsClassifier(n_neighbors=k, weights="distance")
    kNN.fit(X_train, y_train)
    scores[k] = kNN.score(X_test, y_test)

# %%
plt.figure(figsize=(15, 5))
plt.plot(scores.keys(), scores.values())
plt.xlabel("Value of k")
plt.ylabel("Score of model")
# Out:
# Text(0, 0.5, 'Score of model')

# %%
sorted(scores.items(), key=lambda x: x[1], reverse=True)[:10]
# Out:
# [(3, 0.9766081871345029),
#  (9, 0.9766081871345029),
#  (11, 0.9766081871345029),
#  (12, 0.9766081871345029),
#  (13, 0.9766081871345029),
#  (14, 0.9766081871345029),
#  (16, 0.9766081871345029),
#  (6, 0.9707602339181286),
#  (7, 0.9707602339181286),
#  (8, 0.9707602339181286)]

# %% [markdown]
# ### Applying kNN Algorithm with k = 9

# %%
kNN9 = KNeighborsClassifier(n_neighbors=9, weights="distance")

# %%
kNN9.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=9, weights='distance')

# %%
y_pred9 = kNN9.predict(X_test)

# %%
kNN9.score(X_test, y_test)
# Out:
# 0.9766081871345029

# %%
cm3 = metrics.confusion_matrix(y_test, y_pred9, labels=["M", "B"])
cm
# Out:
# array([[ 53,   4],
#        [  2, 112]], dtype=int64)
